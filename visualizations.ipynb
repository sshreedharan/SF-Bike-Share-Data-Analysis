# %%
# Visualizations

import pandas as pd

# Load the data
df_trip = pd.read_csv('dataset_bike_share/trip.csv')
df_weather = pd.read_csv('dataset_bike_share/weather.csv')

# %%
# Model Visualizations
from model import *
full_model(df_trip,df_weather,visual=True,less_features=False)
# Out:
# Linear Regression Model
# Training RMSE: 196.57
# Validation RMSE 201.47
#
# Random Forest Regression Model
# Training RMSE: 95.62
# Validation MSE:  178.16
#
# Neural Network Model
# Training RMSE: 186.18
# Validation RMSE:  202.76
#
# Suppose the weather of a weekday is
# Then the predicted number of daily rentals is 1147
